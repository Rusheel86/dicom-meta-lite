# %%
# !pip install pydicom
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -i https://test.pypi.org/simple dicom-meta-lite
# Out:
# Looking in indexes: https://test.pypi.org/simple
# ...
#   Using cached https://test-files.pythonhosted.org/packages/b9/74/982485959482164744d952e012ca8176d3ad1be994f1c0948ed936cd58df/dicom_meta_lite-0.1.0-py3-none-any.whl.metadata (4.5 kB)
# ...

# %%
from dicom_meta_lite import extract_meta
extract_meta
# Out:
# <function dicom_meta_lite.core.extract_meta(path, keys=None, anonymize=False)>

# %%
print(extract_meta("/content/CT.1.2.246.352.221.4624993143192177652.9922029265889581216.dcm"))
# Out:
# {'PatientID': '1', 'StudyDate': '20241001', 'Modality': 'CT', 'Manufacturer': 'Varian Medical Systems', 'Rows': 512, 'Columns': 512, 'PixelSpacing': [0.96165136990519, 0.96165136990519], 'SliceThickness': '1.99621475530568'}
